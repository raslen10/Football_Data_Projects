# %% [markdown]
# # collect data for  one team (espernace sportive de tunis)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# URL de la page des transferts
url = 'https://www.transfermarkt.fr/ligue-professionnelle-1/transfers/wettbewerb/TUN1'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Faire la requête
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Function to extract data from a table
def extract_table_data(table):
    rows = table.find_all('tr')[1:]  # Skip the header
    data = []
    for row in rows:
        cols = row.find_all('td')
        if len(cols) >= 8:  # Ensure there are enough columns
            player_name = cols[0].get_text(strip=True)
            age = cols[1].get_text(strip=True)
            nationality = cols[2].find('img')['alt'] if cols[2].find('img') else None  # Get the country name
            position = cols[3].get_text(strip=True)
            short_position = cols[4].get_text(strip=True)
            market_value = cols[5].get_text(strip=True)
            # Extracting the club name and country name for the "From" column
            from_team_info = cols[6].find('a')
            if from_team_info:
                from_team = cols[7].get_text(strip=True)
                from_full = f"{from_team} - {nationality}" if nationality else from_team
            else:
                from_full = None
            transfer_fee = cols[8].get_text(strip=True)
            data.append([player_name, age, nationality, position, short_position, market_value, from_full, transfer_fee])
    return data

# %%
# Extraction des données pour les arrivées
table_arrivees = soup.select_one('.box .responsive-table table:nth-of-type(1)')
if table_arrivees:
    arrivees_data = extract_table_data(table_arrivees)
    df_arrivees = pd.DataFrame(arrivees_data)

    # Adding team name and short name columns at the beginning
    df_arrivees.insert(0, 'Team', 'Espérance Sportive de Tunis')
    df_arrivees.insert(1, 'Short Name', 'EST')

    # Renaming columns
    df_arrivees.columns = [
        'Team',  # Added Team column
        'Short Name' , # Added Short Name column
        'Player Name',
        'Age',
        'Nationality',  # Country name
        'Position',
        'Short Position',
        'Market Value',
        'From',  # Team - Country
        'Transfer Fee'

    ]

    print("Arrivals:")
    print(df_arrivees)
else:
    print("Table des arrivées non trouvée.")
# Out:
# Arrivals:
#                            Team Short Name  \
# 0   Espérance Sportive de Tunis        EST
# 1   Espérance Sportive de Tunis        EST
# 2   Espérance Sportive de Tunis        EST
# 3   Espérance Sportive de Tunis        EST
# 4   Espérance Sportive de Tunis        EST
# 5   Espérance Sportive de Tunis        EST
# 6   Espérance Sportive de Tunis        EST
# 7   Espérance Sportive de Tunis        EST
# 8   Espérance Sportive de Tunis        EST
# 9   Espérance Sportive de Tunis        EST
# 10  Espérance Sportive de Tunis        EST
# 11  Espérance Sportive de Tunis        EST
# 12  Espérance Sportive de Tunis        EST
# 13  Espérance Sportive de Tunis        EST
# 14  Espérance Sportive de Tunis        EST
# 15  Espérance Sportive de Tunis        EST
# 16  Espérance Sportive de Tunis        EST
# 17  Espérance Sportive de Tunis        EST
# 18  Espérance Sportive de Tunis        EST
# 19  Espérance Sportive de Tunis        EST
# 20  Espérance Sportive de Tunis        EST
# 21  Espérance Sportive de Tunis        EST
# 22  Espérance Sportive de Tunis        EST
# 23  Espérance Sportive de Tunis        EST
# 24  Espérance Sportive de Tunis        EST
# 25  Espérance Sportive de Tunis        EST
# 26  Espérance Sportive de Tunis        EST
# 27  Espérance Sportive de Tunis        EST
#
#                            Player Name Age     Nationality           Position  \
# 0             Youcef BelaïliY. Belaïli  32         Algérie      Ailier gauche
# 1            Abdramane KonatéA. Konaté  18   Côte d'Ivoire     Milieu central
# 2              Elias MokwanaE. Mokwana  25  Afrique du Sud       Ailier droit
# 3                    Kebba SoweK. Sowe  18          Gambie       Avant-centre
# 4           Bechir Ben SaidB. Ben Said  31         Tunisie     Gardien de but
# 5                Larry AzouniL. Azouni  30         Tunisie     Milieu central
# 6              Hamza JelassiH. Jelassi  32         Tunisie  Défenseur central
# 7      Ayman Ben MohamedA. Ben Mohamed  29         Tunisie     Arrière gauche
# 8            Youssef AbdelliY. Abdelli  25         Tunisie       Avant-centre
# 9            Amanallah MjahedA. Mjahed  20         Tunisie     Arrière gauche
# 10             Koussay MaachaK. Maacha  17         Tunisie       Ailier droit
# 11               Koussay SmiriK. Smiri  20         Tunisie  Défenseur central
# 12                Zinedine KadaZ. Kada  19         Tunisie       Avant-centre
# 13           Amanallah MjahedA. Mjahed  21         Tunisie     Arrière gauche
# 14              Zinedine SassiZ. Sassi  20         Tunisie  Défenseur central
# 15              Zidane LabidiZ. Labidi  21         Tunisie             Milieu
# 16               Hamza GhanmiH. Ghanmi  26         Tunisie     Gardien de but
# 17              Riad BenayadR. Benayad  27         Algérie       Avant-centre
# 18          Khalil GuenichiK. Guenichi  21         Tunisie     Milieu central
# 19           Ghassen MahersiG. Mahersi  23         Tunisie     Arrière gauche
# 20             Abdelaziz KnaniA. Knani  22         Tunisie  Défenseur central
# 21           Youssef MosratiY. Mosrati  24         Tunisie     Milieu central
# 22             Bilel ChabbarB. Chabbar  25         Tunisie  Défenseur central
# 23  Mohamed Rayane HamrouniM. Hamrouni  21         Tunisie      Ailier gauche
# 24            Moemen RahmaniM. Rahmani  25         Tunisie      Ailier gauche
# 25              Wassim KarouiW. Karoui  27         Tunisie     Gardien de but
# 26                Mouhib SelmiM. Selmi  21         Tunisie       Avant-centre
# 27                Wael ChaiebW. Chaieb  20         Tunisie    Milieu offensif
#
#    Short Position Market Value                          From  \
# 0             AiG  1,80 mio. €            MC Alger - Algérie
# 1              MC            -  FC San Pedro - Côte d'Ivoire
# 2             AiD      750 K €   Sekhukhune - Afrique du Sud
# 3              AC      400 K €           AS Soliman - Gambie
# 4             GdB  1,20 mio. €         US Monastir - Tunisie
# 5              MC      450 K €          Al-Faisaly - Tunisie
# 6              DC      500 K €            ES Sahel - Tunisie
# 7             ArG      350 K €         EA Guingamp - Tunisie
# 8              AC      450 K €           Sans club - Tunisie
# 9             ArG       25 K €      Esp. Tunis U21 - Tunisie
# 10            AiD            -     Esperance Tunis - Tunisie
# 11             DC            -      Esp. Tunis U21 - Tunisie
# 12             AC            -      Esp. Tunis U21 - Tunisie
# 13            ArG       25 K €          AS Soliman - Tunisie
# 14             DC       75 K €          AS Soliman - Tunisie
# 15         Milieu       25 K €          AS Soliman - Tunisie
# 16            GdB      175 K €        US Tataouine - Tunisie
# 17             AC      450 K €     Raja Casablanca - Algérie
# 18             MC      250 K €          AS Soliman - Tunisie
# 19            ArG      250 K €        US Tataouine - Tunisie
# 20             DC            -     Ett. Al-Misraty - Tunisie
# 21             MC      300 K €     US Ben Guerdane - Tunisie
# 22             DC      125 K €        Al-Dhahra SC - Tunisie
# 23            AiG      225 K €          AS Soliman - Tunisie
# 24            AiG      225 K €        US Tataouine - Tunisie
# 25            GdB      200 K €          AS Soliman - Tunisie
# 26             AC       50 K €            AS Gabès - Tunisie
# 27             MO       50 K €        US Tataouine - Tunisie
#
#                Transfer Fee
# 0                   679 K €
# 1                   500 K €
# 2                   370 K €
# 3                    90 K €
# 4                 Tr. libre
# 5                 Tr. libre
# 6                 Tr. libre
# 7                 Tr. libre
# 8                 Tr. libre
# 9                         -
# 10                        -
# 11                        -
# 12                        -
# 13  Fin du prêt30 juin 2025
# 14  Fin du prêt30 juin 2024
# 15  Fin du prêt30 juin 2024
# 16  Fin du prêt30 juin 2024
# 17  Fin du prêt30 juin 2024
# 18  Fin du prêt30 juin 2024
# 19  Fin du prêt30 juin 2024
# 20  Fin du prêt30 juin 2024
# 21  Fin du prêt30 juin 2024
# 22  Fin du prêt30 juin 2025
# 23  Fin du prêt30 juin 2024
# 24  Fin du prêt30 juin 2024
# 25  Fin du prêt30 juin 2024
# 26  Fin du prêt30 juin 2024
# 27  Fin du prêt30 juin 2024

# %%
df_arrivees
# Out:
#                            Team Short Name  \
# 0   Espérance Sportive de Tunis        EST
# 1   Espérance Sportive de Tunis        EST
# 2   Espérance Sportive de Tunis        EST
# 3   Espérance Sportive de Tunis        EST
# 4   Espérance Sportive de Tunis        EST
# 5   Espérance Sportive de Tunis        EST
# 6   Espérance Sportive de Tunis        EST
# 7   Espérance Sportive de Tunis        EST
# 8   Espérance Sportive de Tunis        EST
# 9   Espérance Sportive de Tunis        EST
# 10  Espérance Sportive de Tunis        EST
# 11  Espérance Sportive de Tunis        EST
# 12  Espérance Sportive de Tunis        EST
# 13  Espérance Sportive de Tunis        EST
# 14  Espérance Sportive de Tunis        EST
# 15  Espérance Sportive de Tunis        EST
# 16  Espérance Sportive de Tunis        EST
# 17  Espérance Sportive de Tunis        EST
# 18  Espérance Sportive de Tunis        EST
# 19  Espérance Sportive de Tunis        EST
# 20  Espérance Sportive de Tunis        EST
# 21  Espérance Sportive de Tunis        EST
# 22  Espérance Sportive de Tunis        EST
# 23  Espérance Sportive de Tunis        EST
# 24  Espérance Sportive de Tunis        EST
# 25  Espérance Sportive de Tunis        EST
# 26  Espérance Sportive de Tunis        EST
# 27  Espérance Sportive de Tunis        EST
#
#                            Player Name Age     Nationality           Position  \
# 0             Youcef BelaïliY. Belaïli  32         Algérie      Ailier gauche
# 1            Abdramane KonatéA. Konaté  18   Côte d'Ivoire     Milieu central
# 2              Elias MokwanaE. Mokwana  25  Afrique du Sud       Ailier droit
# 3                    Kebba SoweK. Sowe  18          Gambie       Avant-centre
# 4           Bechir Ben SaidB. Ben Said  31         Tunisie     Gardien de but
# 5                Larry AzouniL. Azouni  30         Tunisie     Milieu central
# 6              Hamza JelassiH. Jelassi  32         Tunisie  Défenseur central
# 7      Ayman Ben MohamedA. Ben Mohamed  29         Tunisie     Arrière gauche
# 8            Youssef AbdelliY. Abdelli  25         Tunisie       Avant-centre
# 9            Amanallah MjahedA. Mjahed  20         Tunisie     Arrière gauche
# 10             Koussay MaachaK. Maacha  17         Tunisie       Ailier droit
# 11               Koussay SmiriK. Smiri  20         Tunisie  Défenseur central
# 12                Zinedine KadaZ. Kada  19         Tunisie       Avant-centre
# 13           Amanallah MjahedA. Mjahed  21         Tunisie     Arrière gauche
# 14              Zinedine SassiZ. Sassi  20         Tunisie  Défenseur central
# 15              Zidane LabidiZ. Labidi  21         Tunisie             Milieu
# 16               Hamza GhanmiH. Ghanmi  26         Tunisie     Gardien de but
# 17              Riad BenayadR. Benayad  27         Algérie       Avant-centre
# 18          Khalil GuenichiK. Guenichi  21         Tunisie     Milieu central
# 19           Ghassen MahersiG. Mahersi  23         Tunisie     Arrière gauche
# 20             Abdelaziz KnaniA. Knani  22         Tunisie  Défenseur central
# 21           Youssef MosratiY. Mosrati  24         Tunisie     Milieu central
# 22             Bilel ChabbarB. Chabbar  25         Tunisie  Défenseur central
# 23  Mohamed Rayane HamrouniM. Hamrouni  21         Tunisie      Ailier gauche
# 24            Moemen RahmaniM. Rahmani  25         Tunisie      Ailier gauche
# 25              Wassim KarouiW. Karoui  27         Tunisie     Gardien de but
# 26                Mouhib SelmiM. Selmi  21         Tunisie       Avant-centre
# 27                Wael ChaiebW. Chaieb  20         Tunisie    Milieu offensif
#
#    Short Position Market Value                          From  \
# 0             AiG  1,80 mio. €            MC Alger - Algérie
# 1              MC            -  FC San Pedro - Côte d'Ivoire
# 2             AiD      750 K €   Sekhukhune - Afrique du Sud
# 3              AC      400 K €           AS Soliman - Gambie
# 4             GdB  1,20 mio. €         US Monastir - Tunisie
# 5              MC      450 K €          Al-Faisaly - Tunisie
# 6              DC      500 K €            ES Sahel - Tunisie
# 7             ArG      350 K €         EA Guingamp - Tunisie
# 8              AC      450 K €           Sans club - Tunisie
# 9             ArG       25 K €      Esp. Tunis U21 - Tunisie
# 10            AiD            -     Esperance Tunis - Tunisie
# 11             DC            -      Esp. Tunis U21 - Tunisie
# 12             AC            -      Esp. Tunis U21 - Tunisie
# 13            ArG       25 K €          AS Soliman - Tunisie
# 14             DC       75 K €          AS Soliman - Tunisie
# 15         Milieu       25 K €          AS Soliman - Tunisie
# 16            GdB      175 K €        US Tataouine - Tunisie
# 17             AC      450 K €     Raja Casablanca - Algérie
# 18             MC      250 K €          AS Soliman - Tunisie
# 19            ArG      250 K €        US Tataouine - Tunisie
# 20             DC            -     Ett. Al-Misraty - Tunisie
# 21             MC      300 K €     US Ben Guerdane - Tunisie
# 22             DC      125 K €        Al-Dhahra SC - Tunisie
# 23            AiG      225 K €          AS Soliman - Tunisie
# 24            AiG      225 K €        US Tataouine - Tunisie
# 25            GdB      200 K €          AS Soliman - Tunisie
# 26             AC       50 K €            AS Gabès - Tunisie
# 27             MO       50 K €        US Tataouine - Tunisie
#
#                Transfer Fee
# 0                   679 K €
# 1                   500 K €
# 2                   370 K €
# 3                    90 K €
# 4                 Tr. libre
# 5                 Tr. libre
# 6                 Tr. libre
# 7                 Tr. libre
# 8                 Tr. libre
# 9                         -
# 10                        -
# 11                        -
# 12                        -
# 13  Fin du prêt30 juin 2025
# 14  Fin du prêt30 juin 2024
# 15  Fin du prêt30 juin 2024
# 16  Fin du prêt30 juin 2024
# 17  Fin du prêt30 juin 2024
# 18  Fin du prêt30 juin 2024
# 19  Fin du prêt30 juin 2024
# 20  Fin du prêt30 juin 2024
# 21  Fin du prêt30 juin 2024
# 22  Fin du prêt30 juin 2025
# 23  Fin du prêt30 juin 2024
# 24  Fin du prêt30 juin 2024
# 25  Fin du prêt30 juin 2024
# 26  Fin du prêt30 juin 2024
# 27  Fin du prêt30 juin 2024

# %%
# Check the number of tables to confirm their count
tables = soup.select('.responsive-table table')
print(f"Found {len(tables)} tables.")

# Try accessing the second table directly
if len(tables) > 1:
    table_departs = tables[1]
    departs_data = extract_table_data(table_departs)
    df_departs = pd.DataFrame(departs_data)

    # Adding team name and short name columns at the beginning
    df_departs.insert(0, 'Team', 'Espérance Sportive de Tunis')
    df_departs.insert(1, 'Short Team Name', 'EST')

    # Renaming columns
    df_departs.columns = [
        'Team',
        'Short Tean Name',
        'Player Name',
        'Age',
        'Nationality',
        'Position',
        'Short Position',
        'Market Value',
        'To',  # Team - Country
        'Transfer Fee'
    ]
    print("\nDepartures:")
    print(df_departs)
else:
    print("Table des départs non trouvée.")
# Out:
# Found 32 tables.
#
# Departures:
#                            Team Short Tean Name  \
# 0   Espérance Sportive de Tunis             EST
# 1   Espérance Sportive de Tunis             EST
# 2   Espérance Sportive de Tunis             EST
# 3   Espérance Sportive de Tunis             EST
# 4   Espérance Sportive de Tunis             EST
# 5   Espérance Sportive de Tunis             EST
# 6   Espérance Sportive de Tunis             EST
# 7   Espérance Sportive de Tunis             EST
# 8   Espérance Sportive de Tunis             EST
# 9   Espérance Sportive de Tunis             EST
# 10  Espérance Sportive de Tunis             EST
# 11  Espérance Sportive de Tunis             EST
# 12  Espérance Sportive de Tunis             EST
# 13  Espérance Sportive de Tunis             EST
# 14  Espérance Sportive de Tunis             EST
# 15  Espérance Sportive de Tunis             EST
# 16  Espérance Sportive de Tunis             EST
# 17  Espérance Sportive de Tunis             EST
# 18  Espérance Sportive de Tunis             EST
# 19  Espérance Sportive de Tunis             EST
# 20  Espérance Sportive de Tunis             EST
# 21  Espérance Sportive de Tunis             EST
# 22  Espérance Sportive de Tunis             EST
#
#                                 Player Name Age Nationality  \
# 0                   Houssam GhachaH. Ghacha  28     Algérie
# 1   Mohamed Ali Ben HammoudaM. Ben Hammouda  26     Tunisie
# 2                        Aziz AbidAziz Abid  21     Tunisie
# 3               Ghaylen ChaalaliG. Chaalali  30     Tunisie
# 4                  Zied MachmoumZ. Machmoum  31     Tunisie
# 5                     Oussema ShiliO. Shili  27     Tunisie
# 6          Moez Ben CherifiaM. Ben Cherifia  33     Tunisie
# 7                  Moemen RahmaniM. Rahmani  25     Tunisie
# 8                      Mouhib SelmiM. Selmi  21     Tunisie
# 9                 Ghassen MahersiG. Mahersi  23     Tunisie
# 10                   Zied BerrimaZ. Berrima  23     Tunisie
# 11                     Hani AmamouH. Amamou  26     Tunisie
# 12                    Hamza GhanmiH. Ghanmi  26     Tunisie
# 13                Youssef MosratiY. Mosrati  24     Tunisie
# 14                  Montassar TrikiM. Triki  22     Tunisie
# 15                  Abdelaziz KnaniA. Knani  22     Tunisie
# 16               Khalil GuenichiK. Guenichi  21     Tunisie
# 17                     Aziz FellahA. Fellah  22     Tunisie
# 18       Mohamed Rayane HamrouniM. Hamrouni  21     Tunisie
# 19                      André BukiaA. Bukia  29    RD Congo
# 20                     Wael ChaiebW. Chaieb  20     Tunisie
# 21                Amanallah MjahedA. Mjahed  21     Tunisie
# 22                        Kebba SoweK. Sowe  18      Gambie
#
#              Position Short Position Market Value                         To  \
# 0        Ailier droit            AiD      900 K €        USM Alger - Algérie
# 1        Avant-centre             AC      600 K €       El Mahalla - Tunisie
# 2       Ailier gauche            AiG      150 K €   Olympique Beja - Tunisie
# 3      Milieu central             MC      900 K €          Al-Ahli - Tunisie
# 4       Arrière droit            ArD      150 K €  US Ben Guerdane - Tunisie
# 5      Arrière gauche            ArG      450 K €    Club Africain - Tunisie
# 6      Gardien de but            GdB      500 K €   Olympique Beja - Tunisie
# 7       Ailier gauche            AiG      225 K €        ES Zarzis - Tunisie
# 8        Avant-centre             AC       50 K €         AS Gabès - Tunisie
# 9      Arrière gauche            ArG      250 K €        ES Zarzis - Tunisie
# 10       Avant-centre             AC       50 K €   Stade Tunisien - Tunisie
# 11  Défenseur central             DC      200 K €  Raja Casablanca - Tunisie
# 12     Gardien de but            GdB      175 K €       AS Soliman - Tunisie
# 13     Milieu central             MC      300 K €        ES Zarzis - Tunisie
# 14     Milieu central             MC      175 K €       AS Soliman - Tunisie
# 15  Défenseur central             DC            -   Olympique Beja - Tunisie
# 16     Milieu central             MC      250 K €        ES Zarzis - Tunisie
# 17    Milieu offensif             MO       25 K €         AS Gabès - Tunisie
# 18      Ailier gauche            AiG      225 K €       AS Soliman - Tunisie
# 19       Ailier droit            AiD      350 K €       Sans club - RD Congo
# 20    Milieu offensif             MO            -        Sans club - Tunisie
# 21     Arrière gauche            ArG       25 K €       AS Soliman - Tunisie
# 22       Avant-centre             AC      400 K €        AS Soliman - Gambie
#
#                Transfer Fee
# 0                   250 K €
# 1                    60 K €
# 2                 Tr. libre
# 3                 Tr. libre
# 4                 Tr. libre
# 5                 Tr. libre
# 6                 Tr. libre
# 7                 Tr. libre
# 8                 Tr. libre
# 9                 Tr. libre
# 10                Tr. libre
# 11                Tr. libre
# 12                Tr. libre
# 13                        ?
# 14                     Prêt
# 15                     Prêt
# 16                     Prêt
# 17                     Prêt
# 18                     Prêt
# 19                        -
# 20                        -
# 21                     Prêt
# 22  Fin du prêt30 juin 2024

# %%
df_departs
# Out:
#                            Team Short Tean Name  \
# 0   Espérance Sportive de Tunis             EST
# 1   Espérance Sportive de Tunis             EST
# 2   Espérance Sportive de Tunis             EST
# 3   Espérance Sportive de Tunis             EST
# 4   Espérance Sportive de Tunis             EST
# 5   Espérance Sportive de Tunis             EST
# 6   Espérance Sportive de Tunis             EST
# 7   Espérance Sportive de Tunis             EST
# 8   Espérance Sportive de Tunis             EST
# 9   Espérance Sportive de Tunis             EST
# 10  Espérance Sportive de Tunis             EST
# 11  Espérance Sportive de Tunis             EST
# 12  Espérance Sportive de Tunis             EST
# 13  Espérance Sportive de Tunis             EST
# 14  Espérance Sportive de Tunis             EST
# 15  Espérance Sportive de Tunis             EST
# 16  Espérance Sportive de Tunis             EST
# 17  Espérance Sportive de Tunis             EST
# 18  Espérance Sportive de Tunis             EST
# 19  Espérance Sportive de Tunis             EST
# 20  Espérance Sportive de Tunis             EST
# 21  Espérance Sportive de Tunis             EST
# 22  Espérance Sportive de Tunis             EST
#
#                                 Player Name Age Nationality  \
# 0                   Houssam GhachaH. Ghacha  28     Algérie
# 1   Mohamed Ali Ben HammoudaM. Ben Hammouda  26     Tunisie
# 2                        Aziz AbidAziz Abid  21     Tunisie
# 3               Ghaylen ChaalaliG. Chaalali  30     Tunisie
# 4                  Zied MachmoumZ. Machmoum  31     Tunisie
# 5                     Oussema ShiliO. Shili  27     Tunisie
# 6          Moez Ben CherifiaM. Ben Cherifia  33     Tunisie
# 7                  Moemen RahmaniM. Rahmani  25     Tunisie
# 8                      Mouhib SelmiM. Selmi  21     Tunisie
# 9                 Ghassen MahersiG. Mahersi  23     Tunisie
# 10                   Zied BerrimaZ. Berrima  23     Tunisie
# 11                     Hani AmamouH. Amamou  26     Tunisie
# 12                    Hamza GhanmiH. Ghanmi  26     Tunisie
# 13                Youssef MosratiY. Mosrati  24     Tunisie
# 14                  Montassar TrikiM. Triki  22     Tunisie
# 15                  Abdelaziz KnaniA. Knani  22     Tunisie
# 16               Khalil GuenichiK. Guenichi  21     Tunisie
# 17                     Aziz FellahA. Fellah  22     Tunisie
# 18       Mohamed Rayane HamrouniM. Hamrouni  21     Tunisie
# 19                      André BukiaA. Bukia  29    RD Congo
# 20                     Wael ChaiebW. Chaieb  20     Tunisie
# 21                Amanallah MjahedA. Mjahed  21     Tunisie
# 22                        Kebba SoweK. Sowe  18      Gambie
#
#              Position Short Position Market Value                         To  \
# 0        Ailier droit            AiD      900 K €        USM Alger - Algérie
# 1        Avant-centre             AC      600 K €       El Mahalla - Tunisie
# 2       Ailier gauche            AiG      150 K €   Olympique Beja - Tunisie
# 3      Milieu central             MC      900 K €          Al-Ahli - Tunisie
# 4       Arrière droit            ArD      150 K €  US Ben Guerdane - Tunisie
# 5      Arrière gauche            ArG      450 K €    Club Africain - Tunisie
# 6      Gardien de but            GdB      500 K €   Olympique Beja - Tunisie
# 7       Ailier gauche            AiG      225 K €        ES Zarzis - Tunisie
# 8        Avant-centre             AC       50 K €         AS Gabès - Tunisie
# 9      Arrière gauche            ArG      250 K €        ES Zarzis - Tunisie
# 10       Avant-centre             AC       50 K €   Stade Tunisien - Tunisie
# 11  Défenseur central             DC      200 K €  Raja Casablanca - Tunisie
# 12     Gardien de but            GdB      175 K €       AS Soliman - Tunisie
# 13     Milieu central             MC      300 K €        ES Zarzis - Tunisie
# 14     Milieu central             MC      175 K €       AS Soliman - Tunisie
# 15  Défenseur central             DC            -   Olympique Beja - Tunisie
# 16     Milieu central             MC      250 K €        ES Zarzis - Tunisie
# 17    Milieu offensif             MO       25 K €         AS Gabès - Tunisie
# 18      Ailier gauche            AiG      225 K €       AS Soliman - Tunisie
# 19       Ailier droit            AiD      350 K €       Sans club - RD Congo
# 20    Milieu offensif             MO            -        Sans club - Tunisie
# 21     Arrière gauche            ArG       25 K €       AS Soliman - Tunisie
# 22       Avant-centre             AC      400 K €        AS Soliman - Gambie
#
#                Transfer Fee
# 0                   250 K €
# 1                    60 K €
# 2                 Tr. libre
# 3                 Tr. libre
# 4                 Tr. libre
# 5                 Tr. libre
# 6                 Tr. libre
# 7                 Tr. libre
# 8                 Tr. libre
# 9                 Tr. libre
# 10                Tr. libre
# 11                Tr. libre
# 12                Tr. libre
# 13                        ?
# 14                     Prêt
# 15                     Prêt
# 16                     Prêt
# 17                     Prêt
# 18                     Prêt
# 19                        -
# 20                        -
# 21                     Prêt
# 22  Fin du prêt30 juin 2024

# %% [markdown]
# # collect data for all team ( 16 teams )

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Liste des équipes avec leurs IDs
teams = {
    'EST': '#to-3342',
    'USMO': '#to-9890',
    'CSS': '#to-581',
    'ST': '#to-4812',
    'CA': '#to-819',
    'ESS': '#to-250',
    'OB': '#to-8117',
    'CAB': '#to-12717',
    'EGSG': '#to-18793',
    'UST': '#to-51774',
    'ESM': '#to-39801',
    'ASS': '#to-52128',
    'ESZ': '#to-2205',
    'JSO': '#to-88478',
    'USBG': '#to-30507',
    'ASG': '#to-22812'
}

# URL de la page des transferts
url = 'https://www.transfermarkt.fr/ligue-professionnelle-1/transfers/wettbewerb/TUN1'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Faire la requête
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Fonction pour extraire les données d'une table
def extract_table_data(table):
    rows = table.find_all('tr')[1:]  # Ignorer l'en-tête
    data = []
    for row in rows:
        cols = row.find_all('td')
        if len(cols) >= 8:  # Assurer qu'il y a assez de colonnes
            player_name = cols[0].get_text(strip=True)
            age = cols[1].get_text(strip=True)
            nationality = cols[2].find('img')['alt'] if cols[2].find('img') else None
            position = cols[3].get_text(strip=True)
            short_position = cols[4].get_text(strip=True)
            market_value = cols[5].get_text(strip=True)
            from_team_info = cols[6].find('a')
            from_full = f"{cols[7].get_text(strip=True)} - {nationality}" if from_team_info else None
            transfer_fee = cols[8].get_text(strip=True)
            data.append([player_name, age, nationality, position, short_position, market_value, from_full, transfer_fee])
    return data

# %%
# Listes pour stocker les données des arrivées et départs
all_arrivals = []
all_departures = []

# Boucle à travers les équipes pour extraire les données
for short_name, team_id in teams.items():
    print(f"\nDonnées pour l'équipe: {short_name}")

    # Extraction des données pour les arrivées
    table_arrivees = soup.select_one(f'.box {team_id} + .responsive-table table:nth-of-type(1)')
    if table_arrivees:
        arrivees_data = extract_table_data(table_arrivees)
        for data in arrivees_data:
            data.insert(0, 'Buy')  # Indique que ce sont des arrivées
            data.insert(1, short_name)  # Ajout du nom de l'équipe
            all_arrivals.append(data)
    else:
        print("Table des arrivées non trouvée.")

    # Extraction des données pour les départs
    tables = soup.select('.responsive-table table')
    if len(tables) > 1:
        table_departs = tables[1]  # Deuxième table pour les départs
        departs_data = extract_table_data(table_departs)
        for data in departs_data:
            data.insert(0, 'Sell')  # Indique que ce sont des départs
            data.insert(1, short_name)  # Ajout du nom de l'équipe
            all_departures.append(data)
    else:
        print("Table des départs non trouvée.")

# Création des DataFrames
df_arrivals = pd.DataFrame(all_arrivals, columns=[
    'Buy / Sell',
    'Team',
    'Player Name',
    'Age',
    'Nationality',
    'Position',
    'Short Position',
    'Market Value',
    'From / To',
    'Transfer Fee'
])

df_departures = pd.DataFrame(all_departures, columns=[
    'Buy / Sell',
    'Team',
    'Player Name',
    'Age',
    'Nationality',
    'Position',
    'Short Position',
    'Market Value',
    'From / To',
    'Transfer Fee'
])
# Out:
# Données pour l'équipe: EST
#
# Données pour l'équipe: USMO
#
# Données pour l'équipe: CSS
#
# Données pour l'équipe: ST
#
# Données pour l'équipe: CA
#
# Données pour l'équipe: ESS
#
# Données pour l'équipe: OB
#
# Données pour l'équipe: CAB
#
# Données pour l'équipe: EGSG
#
# Données pour l'équipe: UST
#
# Données pour l'équipe: ESM
#
# Données pour l'équipe: ASS
#
# Données pour l'équipe: ESZ
#
# Données pour l'équipe: JSO
#
# Données pour l'équipe: USBG
#
# Données pour l'équipe: ASG

# %%
# Combiner les DataFrames
df_tun_ligue1_transfer = pd.concat([df_arrivals, df_departures], ignore_index=True)

# Sauvegarder dans un fichier Excel
df_tun_ligue1_transfer.to_excel('tun_ligue1_transfer.xlsx', index=False)

# Affichage des résultats
print("\nDataFrame combiné:")
print(df_tun_ligue1_transfer)
# Out:
# DataFrame combiné:
#     Buy / Sell Team                         Player Name Age     Nationality  \
# 0          Buy  EST            Youcef BelaïliY. Belaïli  32         Algérie
# 1          Buy  EST           Abdramane KonatéA. Konaté  18   Côte d'Ivoire
# 2          Buy  EST             Elias MokwanaE. Mokwana  25  Afrique du Sud
# 3          Buy  EST                   Kebba SoweK. Sowe  18          Gambie
# 4          Buy  EST          Bechir Ben SaidB. Ben Said  31         Tunisie
# ..         ...  ...                                 ...  ..             ...
# 623       Sell  ASG  Mohamed Rayane HamrouniM. Hamrouni  21         Tunisie
# 624       Sell  ASG                 André BukiaA. Bukia  29        RD Congo
# 625       Sell  ASG                Wael ChaiebW. Chaieb  20         Tunisie
# 626       Sell  ASG           Amanallah MjahedA. Mjahed  21         Tunisie
# 627       Sell  ASG                   Kebba SoweK. Sowe  18          Gambie
#
#             Position Short Position Market Value  \
# 0      Ailier gauche            AiG  1,80 mio. €
# 1     Milieu central             MC            -
# 2       Ailier droit            AiD      750 K €
# 3       Avant-centre             AC      400 K €
# 4     Gardien de but            GdB  1,20 mio. €
# ..               ...            ...          ...
# 623    Ailier gauche            AiG      225 K €
# 624     Ailier droit            AiD      350 K €
# 625  Milieu offensif             MO            -
# 626   Arrière gauche            ArG       25 K €
# 627     Avant-centre             AC      400 K €
#
#                         From / To             Transfer Fee
# 0              MC Alger - Algérie                  679 K €
# 1    FC San Pedro - Côte d'Ivoire                  500 K €
# 2     Sekhukhune - Afrique du Sud                  370 K €
# 3             AS Soliman - Gambie                   90 K €
# 4           US Monastir - Tunisie                Tr. libre
# ..                            ...                      ...
# 623          AS Soliman - Tunisie                     Prêt
# 624          Sans club - RD Congo                        -
# 625           Sans club - Tunisie                        -
# 626          AS Soliman - Tunisie                     Prêt
# 627           AS Soliman - Gambie  Fin du prêt30 juin 2024
#
# [628 rows x 10 columns]
